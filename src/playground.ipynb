# %%
from pathlib import Path
import os
import sys

project_root = str(Path(os.getcwd()).parent)
if project_root not in sys.path:
    sys.path.append(project_root)

# %%
from src.toolbox.logger import get_logger
from src.data.dataset_loader import load_dataset

logger = get_logger()
logger.info("Logger initialized")
train_data, test_data = load_dataset("GTSRB", logger)
# Out:
# 12:23:30 - INFO - Logger initialized
# 12:23:30 - INFO - Found downloaded model. Skipping download...
# 12:23:31 - INFO - Shape of training data: 26640
# 12:23:31 - INFO - Shape of test data: 12630

# %%
from src.data.dataset_loader import plot_dataset

plot_dataset(train_data, logger)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[3], line 3
#       1 from src.data.dataset_loader import plot_dataset
# ----> 3 plot_dataset(train_data, logger)
#
# File ~/uni/sem5/ppbm/project/python_lab_course_winter_2025_2026/src/data/dataset_loader.py:72, in plot_dataset(dataset, logger)
#      70 plt.tight_layout()
#      71 plt.show()
# ---> 72 plt.savefig(img_to_plot)
#
# File ~/uni/sem5/ppbm/project/python_lab_course_winter_2025_2026/.venv/lib/python3.12/site-packages/matplotlib/pyplot.py:1250, in savefig(*args, **kwargs)
#    1247 fig = gcf()
#    1248 # savefig default implementation has no return, so mypy is unhappy
#    1249 # presumably this is here because subclasses can return?
# -> 1250 res = fig.savefig(*args, **kwargs)  # type: ignore[func-returns-value]
#    1251 fig.canvas.draw_idle()  # Need this if 'transparent=True', to reset colors.
# ...
